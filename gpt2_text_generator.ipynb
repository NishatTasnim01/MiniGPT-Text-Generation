# %% [markdown]
# **INSTALL DEPENDENCIES**

# %%
# !pip install pypdf2
# Out:
# Collecting pypdf2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: pypdf2
# Successfully installed pypdf2-3.0.1

# %%
# Import Libraries

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer

# Step 1: Load Text from File
def load_text_from_file(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        text = f.read()
    return text

# Step 2: Tokenize Data
tokenizer = AutoTokenizer.from_pretrained("gpt2")  # Use GPT-2 tokenizer for simplicity
def tokenize_text(text, block_size=128):
    tokens = tokenizer.encode(text, add_special_tokens=False)
    sequences = [tokens[i : i + block_size] for i in range(0, len(tokens) - block_size, block_size)]
    return sequences

# Step 3: Create Dataset Class
class TextDataset(Dataset):
    def __init__(self, sequences):
        self.data = torch.tensor(sequences, dtype=torch.long)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx][:-1], self.data[idx][1:]  # Input and target shift by 1

# Step 4: Define a Minimal GPT Model
class MiniGPT(nn.Module):
    def __init__(self, vocab_size, embed_dim=128, num_heads=4, num_layers=5, block_size=128):
        super().__init__()
        self.embed = nn.Embedding(vocab_size, embed_dim)
        self.pos_encoding = nn.Parameter(torch.zeros(1, block_size, embed_dim))
        self.transformer_blocks = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=embed_dim, nhead=num_heads), num_layers
        )
        self.fc_out = nn.Linear(embed_dim, vocab_size)

    def forward(self, x):
        x = self.embed(x) + self.pos_encoding[:, :x.shape[1], :]
        x = self.transformer_blocks(x)
        return self.fc_out(x)

# Step 5: Train the Model
def train_model(model, dataloader, epochs=500, lr=1e-3):
    optimizer = optim.Adam(model.parameters(), lr=lr)
    loss_fn = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        total_loss = 0
        for x, y in dataloader:
            x, y = x.cuda(), y.cuda()
            optimizer.zero_grad()
            outputs = model(x)
            loss = loss_fn(outputs.view(-1, outputs.shape[-1]), y.view(-1))
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        print(f"Epoch {epoch + 1}: Loss = {total_loss / len(dataloader)}")
        if ((epoch + 1) % 10) == 0:
          print("\nGenerated Text:")
          print(generate_text(model, "Oh!", length=500))

# Step 6: Generate Text
def generate_text(model, start_text, length=100, temperature=0.8):
    model.eval()
    input_ids = tokenizer.encode(start_text, return_tensors="pt").cuda()
    generated = input_ids

    for _ in range(length):
        with torch.no_grad():
            logits = model(generated[:, -128:])
            logits = logits[:, -1, :] / temperature  # Apply temperature scaling
            probs = torch.nn.functional.softmax(logits, dim=-1)
            next_token = torch.multinomial(probs, num_samples=1)
            generated = torch.cat([generated, next_token], dim=-1)

    return tokenizer.decode(generated[0].tolist())
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# ### **MAIN EXECUTION STARTS HERE**

# %%
file_path = "harry_potter.txt"  # Path to training text file
text_data = load_text_from_file(file_path)
sequences = tokenize_text(text_data)

dataset = TextDataset(sequences)
dataloader = DataLoader(dataset, batch_size=16, shuffle=True)

vocab_size = tokenizer.vocab_size
model = MiniGPT(vocab_size).cuda()
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (113795 > 1024). Running this sequence through the model will result in indexing errors
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(

# %%
# Train the model
train_model(model, dataloader)

# Final text generation after training
print("\nFinal Generated Text:")
print(generate_text(model, "Okay!", length=5000))
# Out:
# Epoch 1: Loss = 7.40033894777298
# Epoch 2: Loss = 5.754582107067108
# Epoch 3: Loss = 5.220138422080448
# Epoch 4: Loss = 4.861935453755515
# Epoch 5: Loss = 4.615268341132572
# Epoch 6: Loss = 4.426807488713946
# Epoch 7: Loss = 4.269371943814414
# Epoch 8: Loss = 4.137812878404345
# Epoch 9: Loss = 4.0237778680665155
# Epoch 10: Loss = 3.9243767857551575
#
# Generated Text:
# Oh!Well, but he muttered the hat had a spindor, it's why he wanted to the table on the Slytherin' it's the walls, and Harry thinks he wanted to the first one of the first, from it's too as though it is, I'd all the glass, the middle, they were an'ry in time -- he could see that's the first time away from kting curled up to him. "N-Bind," said Ron said.
#
#
# "Just all this is particularly few."
#
# "What's the hall, and the floors to knock the other around theest," said Ron, "But I want to hear the Stone's hut around the cat was called and a large minutes, but it. "Be trunk, but the library."
#
# "Oh, "I will -- but much.
#
# "I've got if yeh name was a.
#
#
#
#
# "This is more money. "We'll be a core his broomstick.
#
#
#
# "And I was going to the year, just smart out both of cloaks, a baby banged the table. "About Harry left to protect you, if he's coming it would have to the house! What it's nothing to me their hearts strangely," said, and a good and Ron."
# "Now, Harry, but Harry.
#
# "Now, I hope it's lose his leg, I'm waiting for him. F twitching the book. Hagrid whispered.
#
#
#
#
#
#
#
#
#
#
#
# There's flick if I'll be the kitchen by the interested in the cloak at all over them, because Neville's nothin' how to the Snitch match around like half an owl, a furiousDudger at the Leaky Cauldron, "You can't bew thought you, you'll have anythin' a long, he was lucky the forest.
# "Griph hundred and got to have a bit of them in his eyes muttered to fly back to be gone off and his defeat of the world!"
# "Is it -- I'm alone. Hagrid, "If that would another.
# "Why too, and last-book on the glass, "Mars. "If you had just a few days.
#
#
#
#
# "All right, Harry and saw it for the first
# Epoch 11: Loss = 3.7856226904051646
# Epoch 12: Loss = 3.691950189215796
# Epoch 13: Loss = 3.614265833582197
# Epoch 14: Loss = 3.5422399597508565
# Epoch 15: Loss = 3.471929166998182
# Epoch 16: Loss = 3.4062361930097853
# Epoch 17: Loss = 3.3263573816844394
# Epoch 18: Loss = 3.2314299813338687
# Epoch 19: Loss = 3.133148436035429
# Epoch 20: Loss = 3.013267810855593
#
# Generated Text:
# Oh! What on fire opposite, velvet. "He's that must know what the other two," said Ron, and beard?"
# "The giant.
# "Move near, who had too small is the coats?" asked. He hadn't know I don't know he had done it out about them."
#
# "But Professor McGonagall along the other hand to hold the portrait of course he had a relief.
#
#
#
# "I've got in here? it on the other hand to himself was there, his gloomy above the exits.
#
#
# "Do you off to buck he's Stone. I haven't understand?" gasped. Harry suddenly.
# The paper. On the open. I hope this in hissed.
#
#
#
#
# Harry tried toad."
#
# It; he'd have done that ruff than a marks weren't be all, and pulled the forest."
# "P-faced Now they were it in, and Fang.
# Harry unfolded, Hermione. "It takes the entrance hall. "You don' he could he was almost forgotten so they'll be surprised I get him," said.
#
#
#
# Harry didn't do the three of the ticketCourse, "We could remember?" whispered, we'd think he looked carefully on the stool to the Ministry of the hall.
#
# "Yes, his head. It was quite gold fell into the wall all, but learn apart o' the dormitory, "No that was skul; Harry. A sign of the softly.
#
#
# He was more, the cloak and Snape's the cloak," said Hagrid, "How FL to get back to this -- nothin' about them.
#
#
#
# "Don' about them.
#
#
# "You found out of course, but taken Norbert and the troll's forehead, Huffle, and Hermione," said Harry, but I've been bounds of the train and said Harry saw the hat and started to seek, Bludley p-looking pub.
# "I have found he couldn't seen with a moment before coming out of the air.
#
#
#
# "Nothing," said, with a second, Harry!"
#
# "You didn't say please for Gryffindor, it grew in his Nim, and beard," said Harry shook his head. Potter," said Hagrid, dark living
# Epoch 21: Loss = 2.8796002183641707
# Epoch 22: Loss = 2.741664183991296
# Epoch 23: Loss = 2.6017879205090657
# Epoch 24: Loss = 2.4622534045151303
# Epoch 25: Loss = 2.3385096532957896
# Epoch 26: Loss = 2.2269385010004044
# Epoch 27: Loss = 2.1229794940778186
# Epoch 28: Loss = 2.038929064358984
# Epoch 29: Loss = 1.9582970568111964
# Epoch 30: Loss = 1.8929335560117448
#
# Generated Text:
# Oh! And this wizard and live -- the letters when the only remember how and ever will be thrown. He was the boys are wandering around the next match.
# Harry, but instead of her to take.
#
# Nev, and looking for him to the cloak, Dumbledore.
# "Well, if we've eyes on the house, and stared, however, the only oneINDORffindor versus peeling floor. "C.
# "I hate j loudly, as Neville, watching-two the school, but as head boy.
#
# "Don't introduced, there. Harry walked out the ground's bin ask first years."
# "Don't find out of the mirror. "We get a nice if he noticed, too disappeared, of the house, "G, they left. He looked as nervous, because he said Harry, however, but Harry.
#
#
#
# "You're going, but Dumbledore was measuring.
# "How the Weasley."
#
# "You've got to convince," said Harry, but the ground gently. Dursley always find outta.
#
# "What was almost knocked out a bit of Malfoy. His face. "Oh, but careful, throwing his body, Ron said Harry leaned forward, "I would be an answer Madam Pom upright and Harry didn't know -- I suppose, I suppose, but he told the snake laughed wound here. "I -- a slightly transparent, which seemed, but it's a good a lot bigger, Ron thought it out to the Stone."
#
#
# "But the ground gently onto his life, waiting, Harry.
# "I you, I've got to the house dormitory, they were up to be a large led the West feet again. The rest, though everything -- I want out, and then showed me?"
#
# "No... hard to be chosen, but a long few, they put the Stone, Harry's not know what they were moving."
# "Yeah," said Ron thought he took the only good a moment, are here," said Harry's not be in. "Well, but Harry's obvious bundle of her to break your head pound, "She kissedh every word toad, Weasley, "What are wandering around a mixture smiled. He couldn't you had gone. It was frightened squeak.
#
# Ron.
#
#
#
#
# "Oh, but
# Epoch 31: Loss = 1.8368490040302277
# Epoch 32: Loss = 1.7871839510543006
# Epoch 33: Loss = 1.7543928367750985
# Epoch 34: Loss = 1.7154935428074427
# Epoch 35: Loss = 1.6825974477188927
# Epoch 36: Loss = 1.65755923305239
# Epoch 37: Loss = 1.6293286042554038
# Epoch 38: Loss = 1.6084124722651072
# Epoch 39: Loss = 1.5894027182034083
# Epoch 40: Loss = 1.5715771956103188
#
# Generated Text:
# Oh! It was the door. I couldn't got to the back of the pre umbrella.
# "Wing boy!" he must have he stop Gryffindor, but now if he cannot! Lare. There mail- doing, brought. Harry noticed their sight.
# "I know all the bottom dad. "I knew it; it's a flying to the week.
#
# When Harry, too.
#
# "Resign!" he pulled them as Ron.
# "Oh, where Dudley's a Qu money?"
#
# "Very the boy, and a hair, that it, we'll be a week. "I --"
#
#
#
# "Don't the first years broken-two.
# "Oh, I could see.
#
#
# "There was now and Harry. "Honestly, Neville?"
#
# He tapped the Dark wizards at the first years," said, he said Harry looked as he could see.
#
#
#
#
# "I suppose, which lay too.
#
#
# "Bin' time to say, which was there.
#
# "You'd be to the first years.
#
#
#
#
# "Oh, was trying to wait, and hardly off his reflection
#
#
# "But the first place, his step, and began to the first years. No heads could see. Harry's Stone, "And then."
#
# "No the castle.
# "All right, but it.
# "Oh, as Percy.
# Harry's only one, and Harry could see, but the We're, but yeh that's name.
#
#
#
#
#
#
#
#
#
# Ron, who's it had just a large woodenked its head. No the first years. The books in the first class.
#
#
# "Don't easy, and looked down to Harry looked as he'd known as Percy. "I have our family within breath. "G chessmen.
#
#
#
#
#
#
#
# "Oh, I'm a word, and Dudley's the car, but I'm not knowing, Snape was still, trying to catch the end of the air.
# "Well, but he could he was still didn't fit -- I mean. "I have done wrong.
#
# "Don't hear footsteps, and Hermione.
#
# "Oh, you seen
# Epoch 41: Loss = 1.5579902231693268
# Epoch 42: Loss = 1.5465732152972902
# Epoch 43: Loss = 1.5264866266931807
# Epoch 44: Loss = 1.5179243790251868
# Epoch 45: Loss = 1.509332639830453
# Epoch 46: Loss = 1.4977343721049172
# Epoch 47: Loss = 1.4895760374409812
# Epoch 48: Loss = 1.483308528150831
# Epoch 49: Loss = 1.4688004340444292
# Epoch 50: Loss = 1.4678722492286138
#
# Generated Text:
# Oh! ALLEYished a chance Restricted Section, "I -- and a blood, he thought there's what to Nor tell Ron.
#
#
#
#
# "I -- I've done if he crept -- and Fall
#
#
# "Brill, "I know about. The people. It took a rather you all the window.
#
#
#
# "Hagrid, are a large bowl. A silver, watery, have some reason to come back on the white of saying of the Stone, which she had let. "I wantedta the way!"
# "You can't do the subtle with glaring. It was already there, but the boy.
#
# "You're keeping his head and Hermione, you think they'd been fighting... the other side of the door.
#
# "I'm not be in the portrait of everything he was the next door. The Dursleys he's not be mad?"
#
#
#
#
#
# "You don't be allowed him.
#
#
# "You don't be mad above his nose -- not see the ground.
# "I know -- he said Ron. He was.
#
# He glared?"
#
#
#
#
#
#
#
#
# "See wait, I'd just for the way down the next street, because they're? It was a sudden believed house?"
#
#
#
#
#
#
# "You don't see the ground. "but Ron, but it. "but Ron.
#
#
#
# "Come on the Dursley was watching him if he's really, he thought Firenze -- I'd better get a week before, "but-Who are! It was about it's head was no," said, and Ron, "It's Stone, "I studying by the ground. He wore than they wanted at the train in the bills and Ron. He had a great keep the first years, and Ron. And make them, the way down the train in the ground.
#
#
# "You don't do as though the other side of them, but it's got to have a week before, but Dumbledore.
#
#
#
# He clambered. The Dursley was almost had been pushed his shoulder. The Dursley's a very white-Who are you think there, and his eyes. The Potters, but you how many three heads, "I -- and
# Epoch 51: Loss = 1.456181334597724
# Epoch 52: Loss = 1.4541949140174049
# Epoch 53: Loss = 1.449832660811288
# Epoch 54: Loss = 1.4402713626623154
# Epoch 55: Loss = 1.4322633147239685
# Epoch 56: Loss = 1.425970373409135
# Epoch 57: Loss = 1.4243740567139216
# Epoch 58: Loss = 1.4193527485643114
# Epoch 59: Loss = 1.4188512180532729
# Epoch 60: Loss = 1.413981835756983
#
# Generated Text:
# Oh! I don't a patch-Who's scar."
# It's all in the Sorcerer's Stone, but it was something about how bad.
# Harry would --"We, "Well, but he would spend the figure's heart, enough, run and I can possibly be a look, "And the ground nervously.
# They don't heard of the first place, saying he's the boy!"
#
# "Well, Yorkshire, I suppose, and grown right, and uncle. Harry shouted.
#
#
# Harry swallowed they had to see.
#
#
# "Oh, boy!" said Harry, there, but he was the Stone, but he said, Huffle Two enormous old house cupboard, but it in the way down and tried to keep his reflection vanished completely as he was holding his reflection (whichbottom, you think it was looking at all they wanted now and then, didn't do as though he'd been entered beat that's Stone, which on the ground.
# Harry followed him..."
#
#
# Harry had been dying the way down the walls. "I have been pushed the door, for his heart, you'll have as they could have been left now walking backward as a moment for the train. "It's Stone, I suppose, and Ron. "I have been many ways.
# Hermione read the door, "I have a sharp. "I have a bit of people. "And now be allowed to be allowed to have been even Ravencl Hogwarts, "We're going to get yer mail, but they had gone.
#
#
# "You don't think they're going to be in the corner.
#
# A be too slow motion was already and they didn't do as Neville.
#
#
#
#
# "You don't a quills, it open. He had gone as Neville, you think again.
# The other and Hermione.
#
#
#
#
#
#
#
#
# Hermione read a very worried, and Hermione. He'd have been sitting back. "I have been quite I suppose, but the forest, but he'd better get expelled.
# "Oh, but it's Stone, but he'd better stay here somewhere, Professor McGonagall. He was going to stop him.
# "I have so close except for him.
#
#
#
#
# "And what I'm not to do as Harry.
# Epoch 61: Loss = 1.407775776726859
# Epoch 62: Loss = 1.3997993894985743
# Epoch 63: Loss = 1.3998189845255442
# Epoch 64: Loss = 1.394296020269394
# Epoch 65: Loss = 1.3932499630110604
# Epoch 66: Loss = 1.3906825206109457
# Epoch 67: Loss = 1.385529569217137
# Epoch 68: Loss = 1.3836752027273178
# Epoch 69: Loss = 1.3774514879499162
# Epoch 70: Loss = 1.3772676182644707
#
# Generated Text:
# Oh! I'll have bothered," said, "We were a most of dragons at a second later. Now... in the first. He keepsves -- and leading them.
#
#
#
# "I know what a troll was running in the plan's your armchairs. A centaur was right in the game plan Seamus, now -- he know what, however, would beaming.
# "No, tearing his partner before we dragged seems to the sp.
# "Dun -- and some money for his favorite subjects.
#
#
# "We'd always been his destiny in that Harry, Aunt Petunia he was going to see. The Dursley around the table.
#
#
# "Goodo," he could see, but they're in a small wooden club, "Look, and Ron.
#
#
#
#
# "Well, he was the kitchen.
#
#
#
#
#
#
# "What are loads of the train. "I've got to bewitched.
#
#
#
# "
#
#
#
#
# Harry's Stone, they had been seen a few seconds, they spotted a lot more than Harry, but Harry, go of the Stone, "I'm sure it.
# "Good of the door.
# He showed a matter anymore, but it. "I'd better his feet.
#
#
# "It was going to be getting out of a nice.
# "The hall. "I'm a matter!" said Harry, but they're not to be yer money for the train.
#
#
#
# "It was a matter!"
#
#
#
#
# "
# "Do you knew. His name, but Harry didn't bewitched.
# "That's it.
#
#
# "What do it was the door.
#
# "So -- he had been fighting that was no sign off the other side, "Oh, they're going to playie or no match.
# "Look, "I've got to stop him.
# "Well, "We'll have done so that's not to say he had been killed there. He was going to the right, we's Stone, but he was going to be too.
# "I warn yehve.
#
# "You don't find out of the ground. He couldn't know --"Oling bellish envelope.
# "This
# Epoch 71: Loss = 1.3723069663558687
# Epoch 72: Loss = 1.3723985701799393
# Epoch 73: Loss = 1.366632953286171
# Epoch 74: Loss = 1.3674406089953013
# Epoch 75: Loss = 1.3652291532073701
# Epoch 76: Loss = 1.359549737402371
# Epoch 77: Loss = 1.3618037679365702
# Epoch 78: Loss = 1.355836638382503
# Epoch 79: Loss = 1.3559877233845847
# Epoch 80: Loss = 1.3508939402444022
#
# Generated Text:
# Oh! How many whiteed off his key and it didn't say he has he was eatingpless three-witched. He'd heard the plan had been given him. He shivered?"
# They'd never understand, petrified, realizing the troll could have blocked by his nostrils. "Don't know... He felt that's a Hogwarts.
# "No -- I'd have done, is it was a few tower. He'd never get us a famous name bin Angelina had gone like to go," said Ron.
# "Just, he'd just as Harry and ran to let that's Professor Quirrell repeated.
#
#
#
#
#
#
# "It's not to his hand.
#
#
# "It was now."
# "We'll be stupid as glowing for the key. He'd heard of the same had a long search of the other two get us."
#
#
#
#
#
#
#
#
# "Don't be very good, we'd just a large stone steps onto the door, but the mail, looking at the door very white pawn had made it was now; he'd just a large owl?"
#
#
#
# "Oh, but Mr.
#
#
# "No, "And what he was no way's not to lose the other two. "It's head and said Harry, because she's not a large box.
# She pulled a letter H.
# Harry didn't Harry.
#
#
#
#
#
#
# So --"Oh, but he'd be in his father's not to do, we know what if he'd just a long an owl."
#
#
#
# "I've got all the girls' time, but it's not be very good a very confused milk bottles.
#
# "Oh, "And then, and Hermione in his hand.
#
#
# "We let go, I'm not knowing he'd just for a few seconds, but it, but it.
#
#
#
#
#
# "It's Stone, we'd just of the train.
#
#
# "Not for the Dursley was still staring around them.
# They don't want to be stupid after Quirrell's Stone, but it. Harry. He'd just ajar knocked out of the only was now all the door, Ron, but there's game now."
#
#
# "It's not knowing he was
# Epoch 81: Loss = 1.3510160169431142
# Epoch 82: Loss = 1.3529549134629113
# Epoch 83: Loss = 1.3468608579465322
# Epoch 84: Loss = 1.3450815443481718
# Epoch 85: Loss = 1.3469617302928651
# Epoch 86: Loss = 1.3438453951052256
# Epoch 87: Loss = 1.3404324714626585
# Epoch 88: Loss = 1.340158068708011
# Epoch 89: Loss = 1.3396461393151964
# Epoch 90: Loss = 1.3359823482377189
#
# Generated Text:
# Oh! I'd think I think.
# "Bulstro makes-two. Norris.
#
#
# "Do not to take away, the whole mind.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "I have a moment he seemed to be allowed to the way. Hermione Granger. They're invisible, Mom."
#
# "Five light, "He's orders.
# THE and tw note at him, the end like a rather you know, but the back and was it gathered closer, so impatiently. It was almost walked the Slytherin' about to explain the next few seconds, I suppose, that's obviously scrawny, no finer.
# "Hagrid's arm.
# "I have been past Fluffy."
# "I have the invisibility cloak and Harry added. Harry noticed them.
#
#
#
#
#
# "Not for sure I'm not to a nice, "It's face. His name, "I'd wanted to try and George? It was almost ran to do the other two.
# "Another one of the front of his uncle and Harry's too?" said Percy of the train this, but no idea of the ground. "I have been because he had been even taller than Harry.
# "It's Stone as he was a large walls.
#
# "I have done so busy against the glass. He was no letterVE by the whole summer and heavy, "I have the pale boy, "I would be able to be allowed to try and said Harry, and Harry.
#
#
# "What's head and said, "But Uncle Vernon, but he's head and said Harry, and said Harry.
#
#
# "
# "Don't see. "I don't find out of them, and you're famous than what looked as he was about my family reckon," said Harry. "I not serious?" said Harry had been pushed in its horrible mistake. He was a funny-and lucky, "Hagrid.
#
#
# "What are flute. He was a few seconds, a few seconds, I think about, "I have been surprised if he was standing around the ground. We'll have got to try and Harry.
#
# "I have been pushed the Stone, "I wouldn't get back.
# "Nearly Headless? I'm sure this,
# Epoch 91: Loss = 1.3371771254709788
# Epoch 92: Loss = 1.3335493121828352
# Epoch 93: Loss = 1.3326262491089957
# Epoch 94: Loss = 1.331547777567591
# Epoch 95: Loss = 1.326597375529153
# Epoch 96: Loss = 1.3292782008647919
# Epoch 97: Loss = 1.3282736114093237
# Epoch 98: Loss = 1.326029387967927
# Epoch 99: Loss = 1.3253408521413803
# Epoch 100: Loss = 1.3218258363859994
#
# Generated Text:
# Oh! How could read the other two cups of the box of the house in the storm motorcycle, it.
# "I've got to fall.
#
#
#
# "
# I'm no proper black ball came to a grip.
# "Don't have it alone.
#
# CHAPTER SIX
#
#
#
#
# Hagrid. Whenever Hagrid leaned over the racket about the green-Know-Who "Look at the common room and working in the next rat was about the mail slot they were his throat.
#
# "Thirty-Anne"I have looked more than me. "I have the other two identical awake. "Go to be doing the door.
# "This isn't think I've got to be mad again. There's not taking the portrait of the other two get there, because he fell on, and saw that's not to see the next," said Hagrid.
# "I'm the mirror and Ron, but Harry's not to be too.
# Then, who's not know -- not to be too. Harry, "I'm the ground, he said Ron, because he could see the ground, but I don't easy-Who's not sitting back to bewitched. He'd be very good a few seconds, they'd have the ground, can't doorknob -- and saw that's not to be very last year, you."
# "
#
#
# "I'm the ground, and Ron, you want to know what was a few seconds, but they were the hat had ever even Ravenclaw large wooden high back to come back to be all the other side of the key.
# "I'm -- they had been so that's not to the one, trying to make them. "I'm up the stool and a few punishments was a low yes," said, who's a few seconds, it was a few seconds, the other side of green they had to come back and he was a few seconds, but he had to look. "You don't bewitched. He must have died. He'd be to come back toad yet.
# Harry's got to come back from the moment for the ground, we had a slight was very last year, the other side of books in a corner at home, and a few seconds, you'd think they heard of green smoke and he was a few seconds, Harry. Dursleys d
# Epoch 101: Loss = 1.3230643421411514
# Epoch 102: Loss = 1.3221665918827057
# Epoch 103: Loss = 1.317254547561918
# Epoch 104: Loss = 1.3208285995892115
# Epoch 105: Loss = 1.3168906016009194
# Epoch 106: Loss = 1.3175135489021028
# Epoch 107: Loss = 1.314255056636674
# Epoch 108: Loss = 1.3136126803500312
# Epoch 109: Loss = 1.3136368542909622
# Epoch 110: Loss = 1.3105480032307761
#
# Generated Text:
# Oh! I want to cheer yet."
# "I wanted to his front step forward, and Voldemort's stomach lur time, and he imagined it.
#
# "Yourck -- it out of the house an' school friends, they had never remember the loud, Professor McGonagall, Harry, their reflections were thudger, and slithering and that's power by the poor were other.
#
#
#
# "Always squeak anxious he readingsivering in the food and a lot here's trunk had been given him.
#
#
#
#
# "You don't got to let go and he'd just a steeply.
# Hermione pointed at all the wall. The evening after the only one of enchantments, a large whole very interesting pop, and said Neville's Stone, the Stone, but they're dead.
# "Dumbledore and looked into a wizard did it, and Ron's got to the corner and saw, but a bit, trying to say he had a few seconds, had been surprised if he said Hagrid, I'd better be too. "I never understand," said Harry, and then became scar; a corner and Ron and Dudley banged it was a bit of them, you know what the door, but she was a small man the wall.
# He rolled up," said Harry's not to go on, the floor.
# "Well, and said Harry. It was very important than the first day for?" said, you, I've got to the way of the best table, and then't got to his hand and fell asleep.
# "You're not sorry around the door, Potter," said, and Harry, with the corner came in the ground. He was a sharp tapest of the way.
#
#
#
#
#
# "What are you can't forgettin' I'd die from the same.
# He opened glowed of the other two -- he was only, as Harry had been dying a holly.
#
#
#
#
#
# "You don't stop him.
#
#
#
#
#
#
#
#
#
# "You're right, but he said, and Ron's Stone is the boy with the way down the wall. "There was a small fortune-and lucky you are you, we'll beamed in a pair of them.
#
#
#
#
#
#
#
#
# "Could plates of parchment, "My thirteen
# Epoch 111: Loss = 1.3098514080047607
# Epoch 112: Loss = 1.3101254062993186
# Epoch 113: Loss = 1.3091518495764052
# Epoch 114: Loss = 1.3092592933348246
# Epoch 115: Loss = 1.3019178467137473
# Epoch 116: Loss = 1.308110162615776
# Epoch 117: Loss = 1.3033230475017004
# Epoch 118: Loss = 1.3022017862115587
# Epoch 119: Loss = 1.302835198385375
# Epoch 120: Loss = 1.3003124126366206
#
# Generated Text:
# Oh! I'll take.
#
#
# "Yer of a tight-quarters at the Muggles.
#
#
#
# A thing he was, watching.
# "
#
# "I, still as he had a wizard that Harry, and Hermione.
# "Did you know a sausage, Percy Weasley, it from breaking his nose in secret.
# "So?"
#
#
#
#
# People stared around Harry leaned forward, could he thought there was good beating wouldn't be it, Harry had gone very tightly as he'd have never been a very who had to send you a deadlying around the train.
# At last year, the ground, but he might belong in the first place, and started to do you've got to be sorted. "but the end of the door.
#
# Hagrid. It was going to the gamekeeper ANDched - - - anyway, we're going to be a word, looking at the Gryffindor, but it was about the ground.
#
#
# "Hagrid's shrieked a few seconds, which was only was the record also got some time to be taken to be learning to get past Fluffy, but the ground.
# "Hagrid.
#
#
#
#
# "Hagrid.
# "I don't be out of the train.
# "You'd better be too.
#
#
#
# "
#
# "I don't stop him. The Potters, the door, but it, "I don't think they were his eyes. The Pottersidered and learn the room. He tried to be mad. "And you think they had been given him. Dursley always favors off his father's Stone, and Ron, but Harry, the door, but it's not see the train.
#
#
# Hagrid. "If you think they won't had been down the corner came to the forest, "And Uncle Vernon, but it.
# Harry had any of the hall, which was a very good to their scar.
#
#
# "Hagrid's not that's doing."
#
#
# "It was on the train. He was a letter. He was imagining things worth of the first years to be too.
# "But you'll be too.
#
#
#
# "I don't such a corner came to the other
# Epoch 121: Loss = 1.3021348459380013
# Epoch 122: Loss = 1.299435066325324
# Epoch 123: Loss = 1.2997086346149445
# Epoch 124: Loss = 1.2984852237360818
# Epoch 125: Loss = 1.2938864529132843
# Epoch 126: Loss = 1.2945911224399294
# Epoch 127: Loss = 1.2949843789849962
# Epoch 128: Loss = 1.295249689902578
# Epoch 129: Loss = 1.2926045315606254
# Epoch 130: Loss = 1.2917899680989129
#
# Generated Text:
# Oh! I'm not going -- and a motorcycle and the boy -- and respect mistake. "We could see!" growled off them."
# "Al look at him.
#
#
# "Wow in the place, because they've already caught the time in the Dursley was the right, and, whatever that Hagrid.
#
#
#
#
#
#
#
#
#
# Professor McGonagall's eleventh school and a copper kettle's not going to his uncle.
#
# "By as though he was a person marked.
#
#
#
#
#
# " just a few old sweater was head and Hermione. "that was trying to go, "but the first years, but it's face?"
# Hermione let go. He'd be too.
# Harry was going to the other two
# "You're going to the mail-faced could make you'd heard something about to do, Harry's name, where they'd better be too nos of them. He was a funny) set off his eyes on the other two are all three of his feet. The old private," said Ron, but they didn't a few seconds, but they might have been sent these words.
# "Oh, Harry.
#
# "Why?" Harry --"Hagrid ran to get out of course, Harry had given him. He was very last. The Potters and a great little teeth and a funny wheed wizard's why they'd ever failed of Harry coming into the train.
#
# "
#
#
#
# "I'm not be out of Magic from the wall.
#
#
#
#
#
# A M's doing they didn't ask you, I'll get rid of course.
# "Hagrid, but it was a sharp in the train. "It's name, but it had been surprised if he's head and his heart sinking. I'm not to find his hand.
#
# "I've ever remember how many last year, but they didn't dare you soon. He'd just streamed, but they'd better be left.
#
# "You've got to do, but they're going to the crate.
# "Neville, but they could get out of course.
#
# The whole hand. Potter, but they'd better go, I suppose, Harry, I've ever remember how bad name, but Ron.
# Then, I've had
# Epoch 131: Loss = 1.2902926611048835
# Epoch 132: Loss = 1.2898550948926382
# Epoch 133: Loss = 1.2892834203583854
# Epoch 134: Loss = 1.2889901612486159
# Epoch 135: Loss = 1.289312251976558
# Epoch 136: Loss = 1.2856600135564804
# Epoch 137: Loss = 1.28822075682027
# Epoch 138: Loss = 1.2859721566949571
# Epoch 139: Loss = 1.2851236845765794
# Epoch 140: Loss = 1.2855355313846044
#
# Generated Text:
# Oh! He was hoping to him, very important for a famous witches stood there, but Mr.
# "Whats right, but Madam Pomfreyboard, but it did plunged for Harry.
# "This is it was at the contrary, one of a black shadows right weighing a look at the table! He remembers and Harry woke with a centaur.)) "We could hear him.
#
# "Makey, Harry moved that somebody came to learn the end of them."
# "
# "Are you see?"
# "
#
# "
#
#
#
#
#
# "Go to the air, "I'm sure it was duffbox was the door.
#
# "Do you've got that's eyes. The empty, but Mr.
#
#
#
#
#
# "There was so meeting in the door, but he had been pushed the door. It was a Blimeing up the invisibility cloak," he said Hagrid. The head, I mean. He'd be very white.
# "They recognized in the portraits gone very nastynobs and the ground.
#
#
#
#
#
#
#
#
# "It was guarding the Stone, which was going to be all right in his feet, "We'll be allowed to stay to be in the way down, which went out into the castle an' light, but it was the lights fork to try and Ron's a long search of the best gamekeeper!"
#
# "
# "Come on the door.
# "What did not to his nose," he had never the first years had a very last year," he'd better be Hermione. The book face?"
# "I've got toad was a few seconds... and it," said. "but the way, the same heavy, you'd be taken from the castle and a very angry?" said Harry Potter, "I'm sure that the Potters and Ron, but he had a few seconds!"
#
#
#
# He usually say he said Dumbledore and Ron, but they walked down, but the centaur was the way down, "If for the other side of Snape, "I've got to be in the ground, have been quite bald at the train three-Who was no meals," said Hermione. "It was the wall. The troll was the first years?"
#
# "I don't do magic over the other side! The hall
# Epoch 141: Loss = 1.2812197506427765
# Epoch 142: Loss = 1.2815189361572266
# Epoch 143: Loss = 1.281444524015699
# Epoch 144: Loss = 1.2829645999840327
# Epoch 145: Loss = 1.2780139637844903
# Epoch 146: Loss = 1.2808837911912374
# Epoch 147: Loss = 1.2786074067865099
# Epoch 148: Loss = 1.2765542353902544
# Epoch 149: Loss = 1.2785670352833611
# Epoch 150: Loss = 1.2768680219139372
#
# Generated Text:
# Oh! How could only one of thing that Malfoy had never let the other. But Nimbus Two Ronnie plain hurry up the Great Hall, but if it was suddenly.
#
# "If yet somehow found him, "we need a game; it is one. Not a step forward, anything, so happygh at the castle, Wood. "It's a coat of course, and a pair of the lead him -- and ambition, grabbed said Harry was searched had almost hidden in the last. This was without then fell, he heard a fat woman 'Jordan!"
# "Don't think I remember...."I'm nothing in a bit of the mailled from the cloak quickly.
#
#
#
#
# Harry followed him," he had ever been extremely flew off his hand. The smell filled light him.
#
# "You think.
#
#
#
# "Don't think I've got to the end of the invisibility cloak quickly. Harry anxiously.
#
# "There's face blister witch an eagle. He was a bad, but the ground.
# Hagrid, but it, "Never and Harry, but he was going to bewitched. Harry, and the other, but Madam Pomfrey came back to be too. They didn't a very last year, the Stone, but he was the Stone."
#
#
#
#
#
#
#
#
# "I'm not to the Slytherin' stupid by the ground. He didn't have a great leap, but it. He was a sharp of the ground. Dudley looked into the pale as Ron, but it.
#
#
#
#
#
#
# "It was a toilet trained, but it. His face, I suppose you, but Harry. He was moving and Goyle, but the ground, but they had been past Flamel, but it.
#
#
#
#
#
#
#
#
#
#
# It's Every Flavor Beans outside the mirror; he should have been doing his hand.
#
#
#
#
# "You know what he had a very worried."
#
# "Don't you in the end of the Gryffindor.
# "I'm not to the Dursleys and started to make you," Hagrid.
#
#
# "I'm not to the wall.
#
#
#
# "
#
#
#
#
#
#
# Hermione let go on it. "We've got to
# Epoch 151: Loss = 1.2764592468738556
# Epoch 152: Loss = 1.2738916043724333
# Epoch 153: Loss = 1.2747722672564643
# Epoch 154: Loss = 1.2735595830849238
# Epoch 155: Loss = 1.274092014346804
# Epoch 156: Loss = 1.2694537426744188
# Epoch 157: Loss = 1.2703426224844796
# Epoch 158: Loss = 1.2714831573622567
# Epoch 159: Loss = 1.2723027297428675
# Epoch 160: Loss = 1.2698400190898351
#
# Generated Text:
# Oh! I'd like cats, Professor McGonagall. Held it.
# It's summat in Godric the steps toward the right, Harry had managed to sleep.
# Harry ignored, put the corridors.
# "I'm sorry, "Snape's the egg and a disgruntled and death, "I don't really, underneath the titles.
#
#
# He rolled up; there wereThing families and Harry.
# "
#
#
#
#
#
# "Oh, I'm so that Hagrid, well wizard's there?"
# "
#
#
#
# "You didn't true he was waiting."
# "You've got your nose."
# "I'm not going to keep his cupboard, but they had gotten the other two."
# "Go to lean.
#
#
# "You know about, but nothing down.
#
#
#
# "I don't find, but before the next to bed next day, and the castle and the way down.
#
# "You'd be too. "I'm not to see the way down. "I'm not to bewitched with a sudden thing is going to Harry.
#
#
# Harry felt.
#
# "Go his cloak, "They fell out.
#
#
# Harry's not know what they had to be allowed to bewitched with a ratherary," he said Harry and the house?"
#
#
# "I don't been doing."
#
#
#
#
#
#
# "
#
#
#
#
#
#
# Hermione read the mail slot. You-Who's legs.
# "B friends, who looked up and his life, he was covered in the cloak, but they were going to bewitched with her. "I'm not going to bewitched from the only one of the table. He was starting to keep him. The head and the letter outside the ground, we've got to his eyes are all right, they didn't have seen any more.
#
# They walked over and then became coming from the doors. I'm so that day, I'm boiling water into the wall. "It's about the wall. Harry. Harry had been younger; Harry's not to save an' dormitory, but it didn't have a few seconds, but there was a very good and Ron, "It's on the gamekeeper.
# Harry had been
# Epoch 161: Loss = 1.2702688915388924
# Epoch 162: Loss = 1.2686740862471717
# Epoch 163: Loss = 1.2678645827940531
# Epoch 164: Loss = 1.2669826107365745
# Epoch 165: Loss = 1.267482612814222
# Epoch 166: Loss = 1.2660240914140428
# Epoch 167: Loss = 1.2646512708493642
# Epoch 168: Loss = 1.2656662549291338
# Epoch 169: Loss = 1.2634177527257375
# Epoch 170: Loss = 1.2629855168717248
#
# Generated Text:
# Oh! I'd like a small, who looked around the school grounds Harry was very difficult, on, you wait, which seemed to say, go, Harry was allowed waved out of his eyes. Then there."
#
# "Doris Crockford, or the last shop. Harry with his cloak," said Harry could read the first week. Harry thought, Ron, he said that fateful but it. As they had the twelve uses with a Bludley -- to London at the Mirror of the boy -- he said something about it.
#
#
# "Well, Neville, Harry scrambled out of the portrait hole little, but he had been a whole often do anything, he had been asked. "And the forest, "You're gonna do the boy!"
# "What do you, but I'm not read the top of the other hand, but they had gone out of the mirror now that he was in the other, Harry noticed that's not think they'd be a corner, the house?"
#
# "No, but it --"What are all?" said Hagrid, but Ron's Stone, but too. "If he said Harry.
#
# "
#
#
#
#
#
#
#
#
# He stopped to the other two are you're going to be able to get the mirror now Charlie. He was a corner, because they've been able to the invisibility cloak, I'd better go."
# "
#
#
#
# It's head and Ron, but it, Harry's not knowing, Ron.
#
# "I'm not have the house, we'd had to bed next to the gamekeeper!"
#
#
#
# He's not to keep his head, I want to keep his heart, the entrance hall. He didn't have gotten the Slytherin'clock there's not read the other two are here --"It's not read the library, it was trying to be a corner, the Dursleys knew.
#
# "What's not.
# "It's got to the Dursleyeeves the mirror now --"
# "No, which she was a few minutes to be in the end of them. They were in the library, where he could have been down, something else.
# "They fell asleep.
#
#
#
#
# "I've got to keep him a few seconds before the castle and the mirror now that's the ground,
# Epoch 171: Loss = 1.2642376848629542
# Epoch 172: Loss = 1.2627087554761343
# Epoch 173: Loss = 1.2610364705324173
# Epoch 174: Loss = 1.2620592096022196
# Epoch 175: Loss = 1.2617161337818419
# Epoch 176: Loss = 1.2594067582062312
# Epoch 177: Loss = 1.261384712798255
# Epoch 178: Loss = 1.257938312632697
# Epoch 179: Loss = 1.258812086922782
# Epoch 180: Loss = 1.2557324745825358
#
# Generated Text:
# Oh! How could bezoarled but it there? And, which he tri on fire.
#
#
# They're going to Harry's off his life. Going at all the sandy-Know-haired tantrum that's had a job hus by the armchairs.
#
#
#
# "Welcome --"Harry layagrid.
# "Gul back out of his own. "Oh, Peeves -- I'd be seeing yeh Hogwarts. There was here -- have the boy, had done, is."
# "But why couldn't know! The people around the room." He turned to the Stone, "It's got up a great lumpy, the wall.
#
#
# "I'm not," said Hagrid looked as though he was a very last. He was a bit of the edge of the Dursley had a sharp week before, Harry, but no. He thought this, both of the door.
#
# Harry felt an'clock the door. Harry.
# Dumbledore is one of the cloak and Hermione, the other two. "I'm not going to be packing his head, I don't bewitched and the door, Harry.
#
#
#
#
#
#
#
#
#
# "
# Harry felt it was no idea of the house.
#
#
# "What about the mirror and thenled toward the house cupboard under his leg. He was a mattercked back to be a small smile out of course. He was too.
#
# "You don' know what's got to be lucky Harry, but no match; Harry, and Snape about the house will be able to be allowed to go," said Dumbledore, you'd better goin' course. They could have the door open.
#
#
#
# "That's a good look. "It's got Morgana!"
#
# "I don' course. "I don't even remember a great lumpy, Harry Potter, and Ron, "How often have known as if he'd better, they were twice his forehead.
#
#
# It was a very fast with the glass, but no owlsy, Harry, but no wonder some time he'd better get back to their first years. He didn't know what you a very interesting about the way back toad, but Harry's head was a small son -- there, that the Dark Arts, the Dursleys meet
# Epoch 181: Loss = 1.2571750708988734
# Epoch 182: Loss = 1.2575743113245283
# Epoch 183: Loss = 1.254683935216495
# Epoch 184: Loss = 1.2549880146980286
# Epoch 185: Loss = 1.2548017970153265
# Epoch 186: Loss = 1.253897290144648
# Epoch 187: Loss = 1.2545534478766578
# Epoch 188: Loss = 1.2514128195387977
# Epoch 189: Loss = 1.251990211861474
# Epoch 190: Loss = 1.2514982691832952
#
# Generated Text:
# Oh! I have the trees.
# Harry felt at the same time came! Exc Christmas," he let that."
# "GO!"
# "Se and other side.
# They had grown back of the mountain troll, fl agreed, so," he was eating the page. Harry's first note, his armgered behind the door.
#
# "So -- how many people had no oh later, but they had to stop him, is it's horrible; there must be somewhere, sit! And a wide, soaring into the end of the three of the difference, Potter, between monkshoodelled at once. "And they had never going to bewitched from the other hand. He didn't tell me, but he was a large box.
# He clambered. It was smiling.
# "There was a lot of the troll was looking up and the name's Stone, but Harry.
#
#
# Harry's name's head onto the library, but I'll see anything that's not taking the table.
#
# Harry had already. "I've got to bewitched. Norris, do you done, but Harry, they had to find his wand has shrieked. He was a large box.
# "I don't want to their way down their way down. That's got to the first years. "There's face.
#
#
# "Gry up!"
#
# "You're up the entrance hall. He was a very interesting bewitched straight to keep his leg, he'd better never even Ravenclaw quiet in his door open. "I don't think he was a lot of the first years."
# "YFFINDOR for the floor. Potter, you'll bewitched alone that's not have been pushed the train.
#
#
# "Hagrid, I did you go," said Hagrid. "I'm holding his eyes.
#
#
# They walked-Who's not going to the way down their way through the door open. He was the We're deep fingers under his father's the Gryffindor common room, and then, I suppose you have I've got to be yer wands, and it.
# "
# "I don't want to bewitched on fire back for the bowl --"Nothing, and a large box. The troll was so he was on, but he said Harry noticed that
# Epoch 191: Loss = 1.2505311029297965
# Epoch 192: Loss = 1.2513327385698045
# Epoch 193: Loss = 1.2532521741730827
# Epoch 194: Loss = 1.2508386160646165
# Epoch 195: Loss = 1.2511221809046609
# Epoch 196: Loss = 1.250297921044486
# Epoch 197: Loss = 1.2487852296658926
# Epoch 198: Loss = 1.248249609555517
# Epoch 199: Loss = 1.2485862523317337
# Epoch 200: Loss = 1.246446620140757
#
# Generated Text:
# Oh! I want to get the dark corridors.
# I have to the dungeon up and read the ingredients in a magnificent mirror...
#
# Harry had a note he didn't know...
#
#
#
# "I have been a bossy, a long golden ribbon flew in a radish and Huffleens of different stars and pulled him in the house cup? Two.
# He gasped.
#
#
#
#
# "There's the Dursley wherever he won't remember sa them copy ("If Ron suddenly.
#
# "Don't go on the motorcycle was gatheringy, Malcolm, the Quidditch robes, but it, they were tell me, and Ron.
#
# "
#
# "I don't seem to the forest at the ground.
# "
#
#
#
#
# "I'm sure it.
# "The Dursley lay silent.
#
#
#
#
#
# "You know anyone, Harry had a very angry?"
#
# "Go on his life, and Ron's not lucky, Harry. Harry told him.
#
#
#
# "Well, who had to the room. They climbed) "I've got to be seeing them.
#
# Hermione remembers!"
#
#
# "I had just now that there, I'll be too.
#
#
#
# He pulled him off to hide for the Gryffindor for the other, but it.
# "Can you think I'd better be yer other two --"
# "
# "Well, he fell out of comfort.
#
#
#
#
# Hermione was the ground, who looked up the mail months. Harry.
#
#
# "There's not allowed to the other teachers FLared in a bit of the first years.
#
# The woman, the room, but he had better bewitched down.
# "You know.
# At last year old indeed in the corner at Harry had never even deeper was almost as Harry had a bit of the grounds Harry had a large stone steps onto the whole house.
#
# "You know about the way down the ground, but Harry, and then he could make them, and Harry and the walls.
# "You know what you know things worth two boys, because they were lucky, but Harry. I just a great lumpy, and Harry was now that Study of them had to join
# Epoch 201: Loss = 1.2461468428373337
# Epoch 202: Loss = 1.2459221482276917
# Epoch 203: Loss = 1.245108766215188
# Epoch 204: Loss = 1.244475552013942
# Epoch 205: Loss = 1.2444897294044495
# Epoch 206: Loss = 1.246180317231587
# Epoch 207: Loss = 1.2412665316036768
# Epoch 208: Loss = 1.2422040062291282
# Epoch 209: Loss = 1.2413130210978645
# Epoch 210: Loss = 1.2411806242806571
#
# Generated Text:
# Oh! Mybingkeeper's not," said Hagrid all the table. "UPucked.
#
# "
#
# "Now, suddenly. I was out of number four was in his element. "Are you -- he was Snape can't mind, Ron, which fell right, yeah, but at least he found Ron and a boog at last. Excuses, at all day, who had to a couple of these words of the invisibility cloak, could he'd be joining team seemed a few start-the he said Harry was up the damp grass, spotted -well, but after weeks.
#
#
#
# He's not sorry, but as he had a very last year there's head, but Harry. "Yes," said Hagrid, but there's a funny smell that's a very last year.
# "You're up the way down their way down on it. "I don't know what?" said, but they were the entrance hall.
#
# "Well, but they were cauldron. I mean. By the others are you're going to be taken from the mirror; Harry's a large order and Ronan. He was standing there were passing an excellent," said Hagrid's not to his face?"
# "You don't dare you.
# "It's a dragon would be a few seconds before, and Ronan, who had been so that's not to Harry.
# "Funny, but Ronan, too.
#
#
#
# THE JOUR," said Hagrid's no match.
# Madam Pomfrey, but they were about the way down their way.
#
#
#
#
#
#
#
#
#
# "You're right, "It's not knowing he could see anything that's a very last year, they've been quite clear to be taken from the other two boys, "Hagrid, but Harry could see.
#
# Harry was a very angry?"
#
#
#
# "Hagrid, which was a few seconds, they didn't seem to keep his fingers, they were they were his eyes.
#
# "Well, but they couldn't stop him a sudden morning, but Professor McGonagall led them. "I'm not to do something out of him -- he said Hagrid's about the other two squares fixed on, I'm not," said. "There's a sudden boy.
#
#
#
#
#
# Epoch 211: Loss = 1.242262942450387
# Epoch 212: Loss = 1.2413913671459471
# Epoch 213: Loss = 1.2414366794484002
# Epoch 214: Loss = 1.2387914061546326
# Epoch 215: Loss = 1.2374060090099062
# Epoch 216: Loss = 1.2392597155911582
# Epoch 217: Loss = 1.2374018601008825
# Epoch 218: Loss = 1.236074909567833
# Epoch 219: Loss = 1.2354577290160316
# Epoch 220: Loss = 1.2382150718144007
#
# Generated Text:
# Oh! It was looking up to Smeltings."
#
# It was very difficult, some of the step; they glowed, otherwise they'd been held out of number four was a large walnut. "Back, Weasley, "Sevent stare, Harry buy a whole minute, there's spell an empty brandy says there might have thought he said in a reflection from the poor on the stairs, they make me sneeocus and Professor McGonagall.
# Harry couldn't imagine.
#
#
#
#
#
# They had just behind them all in? Where became. "They had time to be able to do you, Harry, but I've got to be enjoying them, no brothers have been past Flitwick, Harry. Now...
# "What's not sure you're saying -- he could see the We may never remember what's not to me."
#
#
#
#
# He turned the other two later, but it, but as the first years. "There was a great Muggle world. Malfoy," said Harry's dangerous.
#
# "You know about the hall. Even Hermione, though he said this, and a great tears, but it, but it was now driven out of the other side corridor -- I've got some time, Harry, because he had given him, I'll be following -- and Ron, who looked almost as if he was a few seconds, but it, but I'll be back to be out of the edge of the ground.
# At last. He was a funny smell from Hermione, but it was talking to bewitched apart from the way. Harry.
#
# He tried to be back of the ground, "It's usuallym him, I'd better get out of the train. "And she was a very battered fer a secret weapon, he was a pink face. They're going to be taken from the Leaky Cauldron. It was very interesting about for the only one of course, the floor. Hagrid, but it's head, but I don't you, but it didn't see the door, too.
#
# "I'm not knowing if it, he was the floor.
# "What do you, but he said Harry, as if he said Harry began to the only one of his way.
#
#
# "You'd been younger, the Gryffindor table.
#
#
#
# He turned the door open
# Epoch 221: Loss = 1.2367281402860368
# Epoch 222: Loss = 1.2379407222781862
# Epoch 223: Loss = 1.235824880855424
# Epoch 224: Loss = 1.234363277043615
# Epoch 225: Loss = 1.2336848016296114
# Epoch 226: Loss = 1.2338386476039886
# Epoch 227: Loss = 1.2344793932778495
# Epoch 228: Loss = 1.2327940613031387
# Epoch 229: Loss = 1.2347699701786041
# Epoch 230: Loss = 1.234160995909146
#
# Generated Text:
# Oh! I'm not you'll have a harder she asked. As -- Mr. "for what's your problem isn a pocketed it all right, and a mistake. Dursley had to let's only got back to tell him. "And I will never have get a foot away. I'm meeting you one!"
#
# "Yes? It was the note he'd really knows -- no key.
#
#
# "He's were as he hadn't feel brave or anything that he thought he couldn't have a clean end of the school of trouble to the heart, Uncle Vernon. The minutes he spoke and twelve of a very nervous. The troll's all. It was in the marble drew nearer.
#
#
# He's four hundred and Hermione. Dumbledore, Harry's eye.
#
#
#
# "Don't you're saying he could have been thinking... “
# "I've got to have been given him.
#
#
#
# "I have been given him to beamed off the ground, but it was a very nervous. He was a wizard, because he hadn't know -- and Ron, and Ron, "It's face in the ground, eh?"
# After a very nervously. The Dursley layley looked as Ron moaned and Ron. The room. A scar. Not a big hands with the door, and the door. He was very nervous. He tried to have been thinking... two are you think that's not even a horrible yell. Harry, but Ron, and father's not hurt me off his hand. The castle and Ron, and Hermione. "We'd seen before, but a bit late for some time he had to get one," said Ron, and then he said Ron in his broomsticks over the door open. I want to do the wall.
# "
#
#
#
#
# "I found out of the front of them. The letters when he was a lot of a very large metal as he had a good to make you -- I want to see, but it's not such a large classroom. Harry.
#
# The Bloody Baron slightlya!"
#
# "Oh, the twins.
# "Don't know -- I've got to the other two, but because he was a small, he's not even a very dark common room.
# The Dursleys complained to pull it, Harry, "I'm not going to get us
# Epoch 231: Loss = 1.2330114309276854
# Epoch 232: Loss = 1.230721918599946
# Epoch 233: Loss = 1.2329613438674383
# Epoch 234: Loss = 1.2316833521638597
# Epoch 235: Loss = 1.2311675633702959
# Epoch 236: Loss = 1.2324022757155555
# Epoch 237: Loss = 1.2297314724751882
# Epoch 238: Loss = 1.2286894449165888
# Epoch 239: Loss = 1.2298219821282796
# ...
#
# "The Dursleys'clock in a great adventure practice three of them. "You're going to their heads.
#
#
#
# Harry tried to be in his office?" said Ron. Then he said Hermione, I'm going to the best blankets before the sign of the wall.
#
#
#
#
#
# "What about it, I'm not want to keep him to the glass," said Hagrid, I mean, which was a large birdcage."
# "I don'you think they were a bright blue-headed dog's robes on the wall three of them. "We've got a very angry?"
#
#
# "The Sorting Hat away with the middle of the entrance hall quickly.
#
# "That's not knowing if it, but after a very pleased when the staff room. "I'm going to be easy, and Ron. "We've been looking at the walls, you're going to be allowed to beamed at the Potters away by the fire, but Harry.
# "Now, and it was holding up and then, and fell flat on it.
#
#
# "Yer letters arrived, and Ron and fell asleep.
#
# "Oh, but I got a very worried.
#
#
# The painling, we're going to the hood up to the lock it.
# Harry was very stupid ball or phoenix feather in his cloak," said, Professor McGonagall, though he looked like a bit more than he'd better Hogwarts? I've got to his hand, I think he'd bewitched when they were sitting in the house cup for the fireplace, but a frog ones with a sudden, and then, but it was a very last year, but a very you'd die more than before the gamekeeper, "He's not strong some of the mirror now -- I left now be easy, but it, but he'd bew.
# Hagrid. "I'm armed!"
#
#
#
#
#
# "You're going to his hand. I got to be something about to be in a very worried."
#
#
#
# "I'm nothin' years since a great adventureled Hagrid's not going to be able to be a very strict by his eyes were you are all this reason to be able to the same: "We've got a large troll was a large box.
# "
# Harry felt Harry, and the hat had climbed a great adventure, you're lucky that's a funny Terry and Harry's not cursing.
# He's still as he said.
# "Well, but Harry, but he said Hagrid, I have a very angry?" he stared down.
#
#
#
#
# "Can't be surprised if you're going to Harry asked.
#
# "Can't have to a very worried.
# "A magic out of the library, he was in the We're going to Harry asked Harry asked Ron, I've got to make outta the invisibility cloak," said Hermione.
# "A sister, and Ronan, we've got to Harry and Hermione, as he'd better get back of the door, though he addedsbane, "You'll be in case of his cupboard, Harry. "Nobody before the train. "There was going to a very interested in the waist, and the library window through the cloak," said Harry's not even though he'd better get a very worried. "but we're going to bewitched down and Ron, Harry.
#
#
#
# "A hood up. He was going to each other two weeks, "we are all. "I'm armed!"
#
#
#
#
# "
#
#
# Then she was going to know which was very worried. "I'm armed!" said, and fell asleep.
#
# "I don't think this, he said. "we are these words. Harry asked, and Hermione, I've got a letter, "Yes... maybeed silver Hagrid, he's nothin'you think it was going to be very good to doormat. Harry asked Ron, I'm the High Tableling, we'll take on his wand.
# Hagrid, and he said Hagrid's face, but he said the Gryffindor, he said Professor McGonagall, the postman, "I'm armed!" Ron's the house cupboard.
# "Yes, and Ron.
#
#
#
#
# "Oy man like it was holding up. "You must have done, a great adventure, the hall brought the train. The ghost of the depths of the Potters. But I'm sorry, we're going to the table. Ron, but he was going to say made them.
#
#
#
#
#
#
# "Well, but Harry's eyes, and Ron, he'd better get out of sight; Hermione, I suppose, and the ground.
# "Go on his name's not in the worst around Harry's not strong out of the Gryffindor, but Harry, but Harry.
#
#
#
#
#
# "Well, trying to the way down.
#
#
# "Well, I think he had clenched become put it was going to make out of Harry had to get out of the way down. "we are not sure it, he had seen them.
# "
#
#
#
# "We've got to lower, but he was a very angry?" he hadn't stop him. Harry had a few seconds, you'd better be able to do you'd better do anything, I'm armed!" said, but a very worried. Even split backward. Ron, I'm armed's head, as though he said Professor McGonagall, but a jet prefectsbane, right, you are all. "for the ground.
# He's face, you'd better get out of a word. "There was so did you, but Harry asked.
#
#
#
# Hagrid's best little bronze Knuts than Ron's why he'd done before the wall.
#
#
#
# "What's got to be in his wand. Harry's nothin' this, and Ron.
# The hundreds of a few seconds before lunch. "And now be in his eyes were the Dursley tried to beady the green light his family!" said Harry asked Ronan's Cross. Harry had to the Gryffindor, but he was going to the Gryffindor, we're going to come back to talk to stop him.
# "You've got to be able to have been watching them.
#
#
# The Sorting Ceremony's always been past the next day, which was going toad, "When Harry had a dragon, but I'm Ron, you all the day, "And what they were going to be taken from the library three of them. "There was holding his head, who was a very angry?"
#
#
# "I don't been brought a sudden, Harry had a very worried. Harry's not be learning to the trophy room. He was going to the door.
#
#
#
#
#
#
#
#
#
# Harry tried to doormat.
# "Oh, but Harry looked right, you're going to be in a great leap, I suggest that he said Harry, but Harry, he'd better get back to the other two inches. Harry. "Park ceiling beetle eyes were right, but Harry's nothin'you think you'd better go of the Dark Arts the front of the Stone! Get out of blankets? They're going to find out of a great adventure, Harry. The trouble desperate on his cup.
#
#
#
#
# Hardly. "Oh, he said Harry, I'd better get back to the mail, Harry, I say there, he had a very worried.
# Harry looked like a very worried. "I don't be sickening crash?"
# "We'll be in a very worried.
# "I'm armed!"
#
#
#
#
# "We're not bother him.
# Harry was a few seconds, I'm armed!" said Hagrid's robes on the castle and said.
#
#
# Harry Potter, "You've got to his cupboard, and Ron's not knowing you're gonna be in the other two --"
#
# "I'm Ron. "An'clock in a very stupid did it.
# "Good afternoon, he'd better do magic out of the corridors. He was a very angry?" said Harry's face, which was a great adventure, he could have been so did it's not serious, Harry. "I'm not even deeper Ages.
#
#
#
#
# When the whole arm as he's a group of the front of the matter o'you think he said, "And what you get out of the back to be able to be in his eyes were a dragon, I got to be all the only one more nervous, Harry's, which was carrying a mixture of a sharp again. "I'm armed!" said Ron's not have a bit of the first note, but it.
#
#
#
# "
#
# "What's not knowing if it in the endwered over the cloak," he said Hermione, we're not knowing if it, but he had to their beds at the times."
# Professor McGonagall, I'll be able to come back of a few seconds, the end the door open. His turban with the portrait of a very worried. "You are you are all.
# "Not a few seconds, he'd better change them.
# A breeze and Ron.
# "You're going to beaming.
#
# "Well, but Harry, but Harry. "And there, and Ronan.
# "
#
# "What are you're going to give him.
#
#
#
#
#
# "Can't you're going toad, but it. Harry, but Harry, you, but it's not understand, Harry, Harry, he was a Chocolate."
#
# He's nothin'you think he said Hagrid, but after a few seconds, you? It was going to come back to the library; Filch.
#
# "I'm armedwick, I'm not understand, I'm not even deeper; he said Hagrid's hand. "Wonder us," said, and the invisibility cloak," said Ron.
#
#
#
#
# "You've got to be in his family!"
#
#
# Hagrid, but there, "It was going to be mad --"P-cold watering rapped her mind from the mail slot and Harry. "we neednze," he's a large box.
# "I'm armed had never even though he was in the snakelike, and Ronan's going to his eyes were going to his life, which was going to rob the table.
#
# "I'm armedON results Dudley's still Professor McGonagall, and Ron, trying to the way down.
# "A very strict on the wall.
#
# "It was going to his hand. "We're going to be old man like a trunk like a secret magic out of the house are all the wall.
#
#
# Hermione, but Harry.
# The three of them. "We've got to be in the cat by the corner; he's robes on the fire, which was going to the mirror again. "And there, you know what they were sure that's eyes away with the next to find out of the way upstairs, but Harry, and said, you'd been knocked out of the wall. He was lim up.
#
# The classroom.
#
#
# "It was a very stupid did it's neck, though he wasn't answer! I've got to his hand, but it. It was going to be in his family!"
#
#
#
# Harry's not knowing if it's mine, I'd be able to bewitched down.
#
# "It was going to see what they were looking at the ground. He was going to their way down their ears, Harry.
# "It's robes on the Dark Arts the ground.
# He's robes on his life, you'd better do magic out, "I don't going to do anything, I was a great leap, but it. "I'm not knowing if it. "You're going to the hall quickly. Harry.
#
# "A magic out of them all three of a matter o' smiles open. The feast, I've got a bunch before the air, "Snape's Stone! Anyone wouldn't even though he'd be a very worried. "Everyone see.
# "Oh, I got slowly out of the other.
# Harry's face, too.
# "I'm armed above his trip through the common room. The passagrid's not knowing, no, "We've got to his face, don' know what are you're nothin'you think it's not understand, you'd better change the same: "It was going to find out of the ground.
# Neville was going to his wand. "I'll be very last year -- and Ron's not understand, really once, they were you're going to be staying here --"It's robes on the end the Gryffindor, you're going to his cup, don't want to have been watching them. "It's nearly Christmas ones with the castle and looked as Harry, hard to bewitched.
# Malfoy grinned at once, but he was going to be sickening his name was going to the library window, and walked up in his family!"
#
# "Budge.
#
# "I'm armed!" said Harry had to the other two --"Did you're going to the endwered over the air, I got to the way through his eyes were a very worried."
# "A breezewitching the team hundred and Ron, the mail dashed to be in the players off to his eyes, you'll get out of the whole school, I don't you'll be in the thousands of a few seconds, but Harry heard the ground. The rumor, I suggest that he said Hagrid's robes on the other two -- I'd better get back to be working," said Harry, "We've got some of the edge of them.
#
#
#
#
#
# "A Muggles I suppose, and Harry's nothin'clock in the other two squaresgh -- he'd better get a warm, you'll be sorted, you are all right, I'll be in a few books. "Colly. "We've got to be able to be in his family!"
#
# "A few seconds, you're going to say another little bronze, but Harry, though he'd better get us some of them.
#
# "A lemon drops change the mail, but Harry's a very angry?"
# "Yes, I say there, I'm armed recognized the poor little bronze! Look't use it. "He saw a very battered swish of the library, but it had to be allowed to be a very angry?" said, you'd better get back to calm Ron.
#
# "Not if it, Harry, he said, I'm armed!"
# "You are other two --"Good afternoon, Harry. He was going to do anything, the library three of the hat had toad, but it on his face, like a very stupid ball he was a great adventure, but he said, "He opened his head, you.
#
# "Yeah," said Hermione, but Harry had a bit of the next to him.
#
#
#
# "I'm going to the stool and Ron.
#
# "I don't stay on the mirror, though he said Hermione, I must have been thinking about Quirrell reached the boy, Harry's Stone! Look't think it, and Ron.
#
#
# "A lemon drops knees. Harry's a very interesting late over the common room.
# "You'd better make out of the ceiling lot of a very last year -- there, would be at the house.
#
# The train.
#
# "A Nimbus Dumbledore quietly, and Hermione. "And there, and the other, and the crate. "But Uncle Vernon, we'd better be able to beamed over the same: "Do you're going to keep it.
# Harry nodded.
# Hagrid's face, "we are behind him off to the back to the way down. "Use it. His name was a very worried. Harry had the hall was going to doormat whistled Hagrid, but Harry. "The moonlight and then, they had a small pile of them. "Malfoy wasn't really valuable get yer letters and Ron's not safe enough to the school, but not going to keep it. He was going to be able to be in the last year, he'd better do anything so much."
#
#
# "A sudden player questionled with his hands. The feast, but I've had to go," said. I'm not going to find out of the way down.
#
# Harry picked up. He was open.
#
# "I don't want to get out of the other. The passagrid out of blankets without a large box. He was a great adventure, you, we give him as he said Hagrid.
#
# "A voice spoke. He was going to keep it.
#
#
#
# "I'm armed!"
#
#
# "That's hand.
#
#
#
#
# "Okay, you'd bewitched down their way through a very worried.
#
#
# Harry tried to come back to the back to the mail, but it had to be sickening crashis," said Hagrid, Mr. The feast, Harry, and the grounds.
# He remembers the way out of the common room.
# "I don't want to find out of the train.
# "Oh, "Oh, but I suggest that's a Slytherin' the common room.
# "A hood up the other.
# "Good afternoon, and Ron and the Great Hall, I suppose, Harry had to keep his face. "Or.
#
#
# "Oh, I've got a few seconds, Harry, the library, which was going to his eyes were going to the corner of the same: "It was going to look a bit more fer half pasty man like a very nervously. I suppose --"It's face, and the next to keep his eyes, I mean."
#
#
# "Oh, eh, you'll be too.
# "I don't have been past the Weasleys' himself. Harry. "Fiftyles in a very interested in the kitchen.
#
# "I don't think he'd better get back of the other two dozen right, as they'd better get out of the exams on his head, I'm armed!" said, he'd better doormat.
#
# "Good afternoon, no, Harry.
# "You want to the train.
# "
#
#
#
#
# "That's a very stupid magic out of the middle of them.
#
#
#
#
#
#
# "I'm armed had seen a very tasty, looking at the cheek, but he said Harry, I've got some time to get to their heads.
#
#
# "Oh, Harry Potter for the Potters away from the row. "but I'm armed!"
#
# "Right then, because he hadn't you'd better use it.
# "P-cold watering broomsticks and then, you're famous Harry's the library three-cold watering through the way across the ground.
# Harry Potter, Harry had a very last year, but the wall. Harry, I'd better take them. "sy silver and Ron's face, but a great adventure, but Ron, "is," he said Harry, I'm armed!"
#
#
#
#
#
# "I don't be in his arm as they were the train.
#
# The hundreds of his hand, I'm armed!"
#
#
#
# "Right then, and Ron. "Hagrid's got to the corner of ordinary us some of them. He was in a very worried."
# Uncle Vernon, no one more goblins were too.
# "You're going to be learning to know what they were going to his eyes were too. "For a few seconds, I reckon they'd better doormat. "And there, I'm not knowing if it. The head, I'll be a very strict's not going to keep him to his office, he said Dumbledore's Stone! R."
#
#
# "You're coming out of the size of the other two -- I got a very angry?"
# "
# "We've got to the same: "And now be mad....
#
# "
#
#
#
#
#
# "You're going to the shadows. "Hope a very extra help you're going to go of those letters and the other two -- and said. "I don't you'd had time he'd be in his hand.
#
# Harry was going to go of course, but it. "We've got a big argument with his feet. Harry quickly.
# "Well, I'm armed!"
#
# "You'll be able to do Professor McGonagall, you're not fit the library, and the door!" said.
#
#
# "He's face, I suppose, Hagrid's the air, I'm armed!" said Hagrid, Harry, and Hermione, and Ron's turban.
#
# "It was sharply to be allowed to the mirror again, you're not even though he's face in his face, but Harry asked Ron's face, Harry felt as he'd better beamed at Hogwarts? He was going to him to be able to Romania leaves.
# "Another key. The passagrid's face. "Didn't want to his bags suddenly.
#
#
#
#
#
#
#
# Ron had the corner of laughter. "Snape's head, and he said, but it.
# Harry's not sure it was a very worried. "I think he was going to the edge of us," said Harry, Harry had half past Fl
